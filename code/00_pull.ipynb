# %% [markdown]
# # 00. Pull
#
# **Input:** `../data/raw/Charlotin-hallucination_cases.csv` (Damien Charlotin's AI Hallucination Cases Database).
# **Does:** loads the raw database, prints shape / columns / missingness, writes a snapshot for the next notebook.
# **Output:** `../data/interim/raw.pkl`.
#
# Source: https://www.damiencharlotin.com/hallucinations/

# %%
import pandas as pd
RAW = "../data/raw/Charlotin-hallucination_cases.csv"   # relative path, no hardcoding

# %%
df = pd.read_csv(RAW)
print("rows, cols:", df.shape)
print("\ncolumns:", list(df.columns))
# Out:
# rows, cols: (1848, 18)
#
# columns: ['Case Name', 'Court', 'State(s)', 'Date', 'Party(ies)', 'AI Tool', 'Hallucination Items', 'Outcome', 'Monetary Penalty', 'Professional Sanction', 'Alleged', 'Vendor Disputed', 'Vendor Disputed Explanation', 'Pointer', 'Source', 'Details', 'Legal Field Primary', 'Legal Field Secondary']

# %%
miss = (df.isna().mean()*100).round(1).sort_values(ascending=False)
print("percent missing by column:\n", miss.to_string())
# Out:
# percent missing by column:
#  Vendor Disputed Explanation    99.5
# Monetary Penalty               82.7
# Details                        74.5
# Pointer                        71.8
# Legal Field Secondary          21.0
# Outcome                        20.1
# Legal Field Primary            11.7
# Hallucination Items             5.4
# Source                          2.9
# AI Tool                         0.6
# Court                           0.4
# Party(ies)                      0.3
# State(s)                        0.1
# Date                            0.1
# Case Name                       0.0
# Vendor Disputed                 0.0
# Alleged                         0.0
# Professional Sanction           0.0

# %%
df.to_pickle("../data/interim/raw.pkl")
print("wrote ../data/interim/raw.pkl")
# Out:
# wrote ../data/interim/raw.pkl
